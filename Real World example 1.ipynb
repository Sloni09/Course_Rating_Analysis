# %% [markdown]
# Overview of dataframe

# %%
import pandas
data=pandas.read_csv("reviews.csv",parse_dates=['Timestamp'])
from pytz import utc
from datetime import datetime
import matplotlib.pyplot as plt

# %%
data.head()
# Out:
#                                          Course Name  \
# 0  The Python Mega Course: Build 10 Real World Ap...
# 1  The Python Mega Course: Build 10 Real World Ap...
# 2  The Python Mega Course: Build 10 Real World Ap...
# 3  The Python Mega Course: Build 10 Real World Ap...
# 4  The Python Mega Course: Build 10 Real World Ap...
#
#                    Timestamp  Rating Comment
# 0  2021-04-02 06:25:52+00:00     4.0     NaN
# 1  2021-04-02 05:12:34+00:00     4.0     NaN
# 2  2021-04-02 05:11:03+00:00     4.0     NaN
# 3  2021-04-02 03:33:24+00:00     5.0     NaN
# 4  2021-04-02 03:31:49+00:00     4.5     NaN

# %%
data.shape
# Out:
# (45000, 4)

# %%
data.columns
# Out:
# Index(['Course Name', 'Timestamp', 'Rating', 'Comment'], dtype='object')

# %%
data.hist('Rating')
# Out:
# array([[<AxesSubplot:title={'center':'Rating'}>]], dtype=object)

# %%
data
# Out:
#                                              Course Name  \
# 0      The Python Mega Course: Build 10 Real World Ap...
# 1      The Python Mega Course: Build 10 Real World Ap...
# 2      The Python Mega Course: Build 10 Real World Ap...
# 3      The Python Mega Course: Build 10 Real World Ap...
# 4      The Python Mega Course: Build 10 Real World Ap...
# ...                                                  ...
# 44995                 Python for Beginners with Examples
# 44996  The Python Mega Course: Build 10 Real World Ap...
# 44997  The Python Mega Course: Build 10 Real World Ap...
# 44998                 Python for Beginners with Examples
# 44999  The Python Mega Course: Build 10 Real World Ap...
#
#                        Timestamp  Rating Comment
# 0      2021-04-02 06:25:52+00:00     4.0     NaN
# 1      2021-04-02 05:12:34+00:00     4.0     NaN
# 2      2021-04-02 05:11:03+00:00     4.0     NaN
# 3      2021-04-02 03:33:24+00:00     5.0     NaN
# ...

# %% [markdown]
# Selecting data from data frame

# %%
type(data['Rating'])
# Out:
# pandas.core.series.Series

# %%
data[['Course Name','Rating']]
# Out:
#                                              Course Name  Rating
# 0      The Python Mega Course: Build 10 Real World Ap...     4.0
# 1      The Python Mega Course: Build 10 Real World Ap...     4.0
# 2      The Python Mega Course: Build 10 Real World Ap...     4.0
# 3      The Python Mega Course: Build 10 Real World Ap...     5.0
# 4      The Python Mega Course: Build 10 Real World Ap...     4.5
# ...                                                  ...     ...
# 44995                 Python for Beginners with Examples     4.0
# 44996  The Python Mega Course: Build 10 Real World Ap...     5.0
# 44997  The Python Mega Course: Build 10 Real World Ap...     5.0
# 44998                 Python for Beginners with Examples     5.0
# 44999  The Python Mega Course: Build 10 Real World Ap...     5.0
#
# [45000 rows x 2 columns]

# %% [raw]
# Selecting a row

# %%
data.iloc[4]
# Out:
# Course Name    The Python Mega Course: Build 10 Real World Ap...
# Timestamp                              2021-04-02 03:31:49+00:00
# Rating                                                       4.5
# Comment                                                      NaN
# Name: 4, dtype: object

# %% [markdown]
# ### Selecting multiple row

# %%
data.iloc[1:9]
# Out:
#                                          Course Name  \
# 1  The Python Mega Course: Build 10 Real World Ap...
# 2  The Python Mega Course: Build 10 Real World Ap...
# 3  The Python Mega Course: Build 10 Real World Ap...
# 4  The Python Mega Course: Build 10 Real World Ap...
# 5  The Python Mega Course: Build 10 Real World Ap...
# 6  The Python Mega Course: Build 10 Real World Ap...
# 7  The Python Mega Course: Build 10 Real World Ap...
# 8  The Python Mega Course: Build 10 Real World Ap...
#
#                    Timestamp  Rating Comment
# 1  2021-04-02 05:12:34+00:00     4.0     NaN
# 2  2021-04-02 05:11:03+00:00     4.0     NaN
# 3  2021-04-02 03:33:24+00:00     5.0     NaN
# 4  2021-04-02 03:31:49+00:00     4.5     NaN
# 5  2021-04-02 01:10:06+00:00     4.5     NaN
# 6  2021-04-02 00:44:54+00:00     4.5     NaN
# 7  2021-04-01 23:42:02+00:00     5.0     NaN
# 8  2021-04-01 21:58:40+00:00     5.0     NaN

# %% [markdown]
# ### selecting a section

# %%
data[['Course Name','Rating']].iloc[0:8]
# Out:
#                                          Course Name  Rating
# 0  The Python Mega Course: Build 10 Real World Ap...     4.0
# 1  The Python Mega Course: Build 10 Real World Ap...     4.0
# 2  The Python Mega Course: Build 10 Real World Ap...     4.0
# 3  The Python Mega Course: Build 10 Real World Ap...     5.0
# 4  The Python Mega Course: Build 10 Real World Ap...     4.5
# 5  The Python Mega Course: Build 10 Real World Ap...     4.5
# 6  The Python Mega Course: Build 10 Real World Ap...     4.5
# 7  The Python Mega Course: Build 10 Real World Ap...     5.0

# %% [markdown]
# ### Selecting a cell

# %%
data['Rating'].iloc[3]
# Out:
# 5.0

# %%
data.at[2,'Rating']
# Out:
# 4.0

# %% [markdown]
# ### Filtering Data based on conditions

# %% [markdown]
# ### One Condition

# %%
data[data['Rating'] > 4].mean()
# Out:
# Rating    4.87316
# dtype: float64

# %%
data[data['Comment'] =='NaN']
# Out:
# Empty DataFrame
# Columns: [Course Name, Timestamp, Rating, Comment]
# Index: []

# %%
data['Course Name'].unique()
# Out:
# array(['The Python Mega Course: Build 10 Real World Applications',
#        'The Complete Python Course: Build 10 Professional OOP Apps',
#        '100 Python Exercises I: Evaluate and Improve Your Skills',
#        'Interactive Data Visualization with Python and Bokeh',
#        'Python for Beginners with Examples',
#        'Data Processing with Python',
#        '100 Python Exercises II: Evaluate and Improve Your Skills',
#        'Learn GIS in One Hour'], dtype=object)

# %% [markdown]
# ### Multiple Condition

# %%
data[(data['Course Name'] =='The Python Mega Course: Build 10 Real World Applications') & (data['Rating'] >= 4)]['Rating'].mean()
# Out:
# 4.6769645019437895

# %% [markdown]
# ### Time-Based Filtering

# %%
data[(data['Timestamp'] >= datetime(2020,7,1, tzinfo=utc) ) & (data['Timestamp'] <= datetime(2020,12,31, tzinfo=utc))]
# Out:
#                                             Course Name  \
# 3065  Interactive Data Visualization with Python and...
# 3066  The Python Mega Course: Build 10 Real World Ap...
# 3067  The Python Mega Course: Build 10 Real World Ap...
# 3068  The Python Mega Course: Build 10 Real World Ap...
# 3069  The Python Mega Course: Build 10 Real World Ap...
# ...                                                 ...
# 9729  The Python Mega Course: Build 10 Real World Ap...
# 9730  The Python Mega Course: Build 10 Real World Ap...
# 9731  The Python Mega Course: Build 10 Real World Ap...
# 9732  The Python Mega Course: Build 10 Real World Ap...
# 9733  The Python Mega Course: Build 10 Real World Ap...
#
#                      Timestamp  Rating  \
# 3065 2020-12-30 23:28:34+00:00     3.0
# 3066 2020-12-30 22:59:02+00:00     4.0
# 3067 2020-12-30 22:40:10+00:00     4.5
# 3068 2020-12-30 21:56:41+00:00     4.5
# 3069 2020-12-30 21:14:34+00:00     4.5
# ...                        ...     ...
# ...

# %% [markdown]
# ### From data to information

# %%
data['Rating'].mean()
# Out:
# 4.442155555555556

# %% [markdown]
# ### Average for a particular plot

# %%
data[data['Course Name']=='Python for Beginners with Examples']['Rating'].mean()
# Out:
# 4.300974901472723

# %% [markdown]
# ### Average Rating for particular period

# %%
data[(data['Timestamp'] >= datetime(2020,7,1,tzinfo=utc)) &
      (data['Timestamp'] <= datetime(2020,10,1,tzinfo=utc))]['Rating'].mean()
# Out:
# 4.4928995610637745

# %% [markdown]
# ### Avg rating for particular couse and period

# %%
data[(data['Timestamp'] >= datetime(2020,7,1,tzinfo=utc)) &
      (data['Timestamp'] <= datetime(2020,10,1,tzinfo=utc)) &
    (data['Course Name']== 'Interactive Data Visualization with Python and Bokeh')]['Rating'].mean()
# Out:
# 4.5

# %% [markdown]
# ### Avg of uncommented rating

# %%
data[data['Comment'].isnull()]['Rating'].mean()
# Out:
# 4.433679746603492

# %% [markdown]
# ### Avg of commented rating

# %%
data[data['Comment'].notnull()]['Rating'].mean()
# Out:
# 4.489777908515959

# %% [markdown]
# ### Number of uncommented rating

# %%
data[data['Comment'].isnull()]['Rating'].count()
# Out:
# 38201

# %% [markdown]
# ### number of commented rating

# %%
data[data['Comment'].notnull()]['Rating'].count()
# Out:
# 6799

# %% [markdown]
# ### Number of comments containing a certain word

# %%
data[data['Comment'].str.contains('python',na=False)].count()
# Out:
# Course Name    857
# Timestamp      857
# Rating         857
# Comment        857
# dtype: int64

# %% [markdown]
# ### Avg of commented rating with "python" in comment

# %%
data[data['Comment'].str.contains('python',na=False)]['Rating'].mean()
# Out:
# 4.537922987164527

# %% [markdown]
# ### Data Visualization

# %%
data['Day'] = data['Timestamp'].dt.date
#data.head()
day_average = data.groupby(['Day'])
day_average['Rating'].mean()
# Out:
# Day
# 2018-01-01    4.532609
# 2018-01-02    4.122807
# 2018-01-03    4.360465
# 2018-01-04    4.531250
# 2018-01-05    4.423077
#                 ...
# 2021-03-29    4.240000
# 2021-03-30    4.428571
# 2021-03-31    4.453125
# 2021-04-01    4.592593
# 2021-04-02    4.357143
# Name: Rating, Length: 1188, dtype: float64

# %%
plt.figure(figsize=(25,3))
plt.plot(day_average.index,day_average['Rating'])

# %%
day_average['Rating'].min()
# Out:
# 3.7916666666666665

# %%
day_average['Rating'].max()
# Out:
# 5.0

# %% [markdown]
# ### Rating averge by week

# %%
data['Week'] = data['Timestamp'].dt.strftime('%m-%U')
week_average=data.groupby(['Week']).mean()
week_average['Rating']
plt.figure(figsize=(25,3))
plt.plot(week_average.index,week_average['Rating'])
#day_average1 = data.groupby(['Week'])

# %% [markdown]
# ### Average rating by month

# %%
data['Month'] = data['Timestamp'].dt.strftime('%Y-%m')
month_average=data.groupby(['Month']).mean()
month_average['Rating']
plt.figure(figsize=(25,3))
plt.plot(month_average.index,month_average['Rating'])
#day_average1 = data.groupby(['Week'])

# %% [markdown]
# ### average rating by month by course

# %%
data['Month'] = data['Timestamp'].dt.strftime('%Y-%m')
month_average_course = data.groupby(['Month','Course Name'])['Rating'].mean().unstack()
month_average_course.plot(figsize=(25,8))
#plt.plot('Course Name',month_average_course['Rating'])
#data.head()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
month_average.head()
# Out:
#            Rating        Day
# Month
# 2018-01  4.429645   2.655738
# 2018-02  4.436248   6.936248
# 2018-03  4.421671  11.411662
# 2018-04  4.468211  15.322434
# 2018-05  4.396420  19.907845

# %%
month_average_course
# Out:
#                                                            Timestamp  \
# Course Name 100 Python Exercises I: Evaluate and Improve Your Skills
# Month
# 2018-01                                                   58.0
# 2018-02                                                   36.0
# 2018-03                                                   46.0
# 2018-04                                                   29.0
# 2018-05                                                   46.0
# 2018-06                                                   41.0
# 2018-07                                                   28.0
# 2018-08                                                   41.0
# 2018-09                                                   44.0
# 2018-10                                                   33.0
# 2018-11                                                   47.0
# 2018-12                                                   58.0
# 2019-01                                                   41.0
# ...

# %% [markdown]
# ### what day are people  happiest?

# %%
data['Weekday']=data['Timestamp'].dt.strftime('%A')
data['Daynumber']=data['Timestamp'].dt.strftime('%w')

weekday_average=data.groupby(['Weekday','Daynumber']).mean()
weekday_average=weekday_average.sort_values('Daynumber')

weekday_average.index.get_level_values(0)
plt.figure(figsize=[15,3])
plt.plot(weekday_average.index.get_level_values(0),weekday_average['Rating'])

# %% [markdown]
# ### Different types of plot

# %%
dir(plt)
# Out:
# ['Annotation',
#  'Arrow',
#  'Artist',
#  'AutoLocator',
#  'Axes',
#  'Button',
#  'Circle',
#  'Figure',
#  'FigureCanvasBase',
#  'FixedFormatter',
#  'FixedLocator',
#  'FormatStrFormatter',
#  'Formatter',
#  'FuncFormatter',
#  'GridSpec',
#  'IndexLocator',
#  'Line2D',
#  'LinearLocator',
#  'Locator',
#  'LogFormatter',
#  'LogFormatterExponent',
#  'LogFormatterMathtext',
#  'LogLocator',
#  'MaxNLocator',
#  'MouseButton',
#  'MultipleLocator',
#  'Normalize',
#  'NullFormatter',
#  'NullLocator',
#  'Number',
#  'PolarAxes',
#  'Polygon',
#  'Rectangle',
#  'ScalarFormatter',
#  'Slider',
#  'Subplot',
#  'SubplotTool',
#  'Text',
#  'TickHelper',
#  'Widget',
#  '_INSTALL_FIG_OBSERVER',
#  '_IP_REGISTERED',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_auto_draw_if_interactive',
#  '_backend_mod',
#  '_code_objs',
#  '_copy_docstring_and_deprecators',
# ...

# %%
help(plt.pie)
# Out:
# Help on function pie in module matplotlib.pyplot:
#
# pie(x, explode=None, labels=None, colors=None, autopct=None, pctdistance=0.6, shadow=False, labeldistance=1.1, startangle=0, radius=1, counterclock=True, wedgeprops=None, textprops=None, center=(0, 0), frame=False, rotatelabels=False, *, normalize=None, data=None)
#     Plot a pie chart.
#
#     Make a pie chart of array *x*.  The fractional area of each wedge is
#     given by ``x/sum(x)``.  If ``sum(x) < 1``, then the values of *x* give
#     the fractional area directly and the array will not be normalized. The
#     resulting pie will have an empty wedge of size ``1 - sum(x)``.
#
#     The wedges are plotted counterclockwise, by default starting from the
#     x-axis.
#
#     Parameters
#     ----------
#     x : 1D array-like
#         The wedge sizes.
#
#     explode : array-like, default: None
#         If not *None*, is a ``len(x)`` array which specifies the fraction
# ...

# %% [markdown]
# ### Number of rating by course

# %%
share=data.groupby(['Course Name'])['Rating'].mean()
share
# Out:
# Course Name
# 100 Python Exercises I: Evaluate and Improve Your Skills      4.323603
# 100 Python Exercises II: Evaluate and Improve Your Skills     4.519643
# Data Processing with Python                                   4.237327
# Interactive Data Visualization with Python and Bokeh          4.275098
# Learn GIS in One Hour                                         4.071142
# Python for Beginners with Examples                            4.300975
# The Complete Python Course: Build 10 Professional OOP Apps    4.623404
# The Python Mega Course: Build 10 Real World Applications      4.477270
# Name: Rating, dtype: float64

# %%
plt.figure(figsize=(45,5))
plt.plot(share)
